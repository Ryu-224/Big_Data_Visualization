# %% [markdown]
# # 안녕하세요
# ## 안녕하세요
# ### 안녕하세요
# #### 안녕하세요
# ##### 안녕하세요
#
# **혼공 분석**
# _혼공 분석_
# ~~혼공 분석~~
# >혼공 분석
# * 혼공 분석
# - 혼공 분석
#
# [한빛미디어](http://www.hanbit.co.kr/)
# ![한빛미디어](data:image/png;base64,...)
#
# $ y = x \times z$

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
seconds_in_a_week = 24 * 60 * 60 * 7
seconds_in_a_week
# Out:
# 604800

# %%
seconds_in_a_week = 0
seconds_in_a_week
# Out:
# 0

# %%
import pandas as pd
df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2026년 02월).csv')
# Out:
# /tmp/ipykernel_1355/3132961764.py:2: DtypeWarning: Columns (5,7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('서울특별시교육청남산도서관 장서 대출목록 (2026년 02월).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462631 entries, 0 to 462630
# Data columns (total 14 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   번호           462631 non-null  int64
#  1   도서명          462231 non-null  object
#  2   저자           462421 non-null  object
#  3   출판사          456806 non-null  object
#  4   발행년도         462585 non-null  object
#  5   ISBN         462631 non-null  object
#  6   세트 ISBN      27496 non-null   float64
#  7   부가기호         339813 non-null  object
#  8   권            72039 non-null   object
#  9   주제분류번호       438399 non-null  object
#  10  도서권수         462631 non-null  int64
#  11  대출건수         462631 non-null  int64
#  12  등록일자         462631 non-null  object
#  13  Unnamed: 13  0 non-null       float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 49.4+ MB

# %%
df
# Out:
#             번호                    도서명                           저자     출판사  \
# 0            1             눈과 보이지 않는   데이브 에거스 글 ;숀 해리스 그림 ;송섬별 옮김  위즈덤하우스
# 1            2            설탕 실(독서치료용)                          연소민  자이언트북스
# 2            3       소란한 비밀:강은지 장편소설                        강은지 지음      창비
# 3            4  어부바 앱에 접속하셨습니다(독서치료용)                          김경미    슈크림북
# 4            5           럭키 펀치(독서치료용)                          이송현    다산책방
# ...        ...                    ...                          ...     ...
# 462626  462627              음악이 있는 풍경                       김정환 지음  이론과 실천
# 462627  462628                    큰오빠                       박정근 지음   우리문학사
# 462628  462629                  뉴 웨이브                   제임스 모나코 지음     한나래
# 462629  462630           (최인훈 장편소설)화두                       최인훈 지음     민음사
# 462630  462631           독일 문학과 세계 문학                       吳漢鎭 編著      벽호
#
#         발행년도           ISBN       세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 0       2024  9791171712359           NaN    7  NaN     843     1     0
# 1       2026  9791191824520           NaN  NaN  NaN     NaN     1     0
# 2       2026  9788936457433           NaN    4  NaN   813.7     1     0
# 3       2026  9791124223048           NaN  NaN  NaN     NaN     1     0
# 4       2026  9791130674490           NaN  NaN  NaN     NaN     1     0
# ...      ...            ...           ...  ...  ...     ...   ...   ...
# 462626  1998  9788931370010           NaN  NaN    2   670.4     1     0
# 462627  1998  9788974231323           NaN  NaN    2   813.6     2     0
# 462628  1996  9788985367448           NaN  NaN    2  688.04     1     0
# 462629  1994  9788937401596  9.788937e+12  NaN    2   813.6     1     0
# 462630  1995  9788947700368           NaN  NaN    3  809.05     2     0
#
#               등록일자  Unnamed: 13
# 0       2026-02-27          NaN
# 1       2026-02-27          NaN
# 2       2026-02-27          NaN
# 3       2026-02-27          NaN
# 4       2026-02-27          NaN
# ...            ...          ...
# 462626  1970-01-01          NaN
# 462627  1970-01-01          NaN
# 462628  1970-01-01          NaN
# 462629  1970-01-01          NaN
# 462630  1970-01-01          NaN
#
# [462631 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# 번호                  0
# 도서명               400
# 저자                210
# 출판사              5825
# 발행년도               46
# ISBN                0
# 세트 ISBN        435135
# 부가기호           122818
# 권              390592
# 주제분류번호          24232
# 도서권수                0
# 대출건수                0
# 등록일자                0
# Unnamed: 13    462631
# dtype: int64

# %%
loan_df = df[df['대출건수'] > 0]
loan_df
# Out:
#             번호                                              도서명  \
# 921        922                      AI로 차트, 그래프, 인포그래픽 한 번에 끝내기
# 922        923                            흑해 :세상의 중심이 된 바다의 역사
# 923        924  신병주의 라이벌로 읽는 한국사 :삼국시대에서 조선시대까지 한국사를 바꾼 31번의 선택
# 924        925                                             누에나방
# 925        926                                마지막 방화 :조영주 장편소설
# ...        ...                                              ...
# 462082  462083                                          중국고대사상사
# 462227  462228                                발표력, 웅변, 동화 지도 교재
# 462367  462368                                       쉽게 찾는 우리 꽃
# 462387  462388                                   갈팡질팡 뒤죽박죽 허겁지겁
# 462417  462418                                       호랑이는 뿔이 없다
#
#                      저자           출판사  발행년도           ISBN  세트 ISBN 부가기호    권  \
# 921               이현 지음          천그루숲  2026  9791193000861      NaN  NaN  NaN
# 922     찰스 킹 지음 ;고광열 옮김           사계절  2026  9791169814171      NaN  NaN  NaN
# 923              신병주 지음  한즈미디어(한스미디어)  2026  9791124272077      NaN  NaN  NaN
# 924               마태 지음        해피북스투유  2026  9791170965725      NaN  NaN  NaN
# 925            지은이: 조영주         한겨레출판  2026  9791172133719      NaN  NaN  NaN
# ...                 ...           ...   ...            ...      ...  ...  ...
# 462082            郭沫若 저           김영사  1991  9788934900153      NaN  NaN  NaN
# 462227              편기범           民音社  1993  9788937410055      NaN  NaN  NaN
# 462367           김태정 지음            정일  1994  9788985119320      NaN  NaN    2
# 462387      세계로가는 기차 지음         민서출판사  1994  9788942200290      NaN  NaN  NaN
# 462417           김성길 지음           民音社  1993  9788937400445      NaN  NaN    上
#
#           주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 921       004.73     1     1  2026-02-23          NaN
# 922          909     1     1  2026-02-23          NaN
# 923          911     1     1  2026-02-23          NaN
# 924        813.7     1     1  2026-02-23          NaN
# 925        813.7     1     1  2026-02-23          NaN
# ...          ...   ...   ...         ...          ...
# 462082     152.2     1     1  1970-01-01          NaN
# 462227     802.5     1     1  1970-01-01          NaN
# 462367  481.9911     1     1  1970-01-01          NaN
# 462387     980.2     2     1  1970-01-01          NaN
# 462417     813.6     3     2  1970-01-01          NaN
#
# [400403 rows x 14 columns]

# %%
with open('서울특별시교육청남산도서관 장서 대출목록 (2026년 02월).csv') as f:
  print(f.readline())
  print(f.readline())
  print(f.readline())
  print(f.readline())
# Out:
# ﻿번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","눈과 보이지 않는 ","데이브 에거스 글 ;숀 해리스 그림 ;송섬별 옮김","위즈덤하우스","2024","9791171712359","","7","","843","1","0","2026-02-27",
#
# "2","설탕 실(독서치료용)","연소민","자이언트북스","2026","9791191824520","","","","","1","0","2026-02-27",
#
# "3","소란한 비밀:강은지 장편소설 ","강은지 지음","창비","2026","9788936457433","","4","","813.7","1","0","2026-02-27",

# %%
import chardet
with open('서울특별시교육청남산도서관 장서 대출목록 (2026년 02월).csv', mode = 'rb') as f:
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'UTF-8-SIG', 'confidence': 1.0, 'language': ''}

# %% [markdown]
# ## 코랩에서 데이터 확인하기

# %%
import gdown

gdown.download('https://bit.ly/3eecMKZ', '남산도서관 장서 대출목록 (2021년 04월).csv', quiet = False)
# Out:
# Downloading...
# From: https://bit.ly/3eecMKZ
# To: /content/남산도서관 장서 대출목록 (2021년 04월).csv
# 100%|██████████| 58.1M/58.1M [00:00<00:00, 179MB/s]
# '남산도서관 장서 대출목록 (2021년 04월).csv'

# %% [markdown]
# ### 파이썬으로 CSV 파일 출력하기

# %%
with open('남산도서관 장서 대출목록 (2021년 04월).csv') as f:
  print(f.readline())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_1355/1180962475.py in <cell line: 0>()
#       1 with open('남산도서관 장서 대출목록 (2021년 04월).csv') as f:
# ----> 2   print(f.readline())
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb9 in position 0: invalid start byte

# %%
import chardet

with open('남산도서관 장서 대출목록 (2021년 04월).csv', mode = 'rb') as f:
  d = f.readline()

print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('남산도서관 장서 대출목록 (2021년 04월).csv', encoding = 'EUC-KR') as f:
  print(f.readline())
  print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","인공지능과 흙","김동훈 지음","민음사","2021","9788937444319","","","","","1","0","2021-03-19",

# %%
import os
import glob
import unicodedata

for filename in glob.glob('*.csv'):
  nfc_filename = unicodedata.normalize('NFC', filename)
  os.rename(filename, nfc_filename)

# %% [markdown]
# ## 데이터프레임 다루기: 판다스

# %%
import pandas as pd
df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding = 'EUC-KR')
# Out:
# /tmp/ipykernel_1355/1184723811.py:2: DtypeWarning: Columns (5,6,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding = 'EUC-KR')

# %%
df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding = 'EUC-KR', low_memory = False)

# %%
df = pd.read_csv('남산도서관 장서 대출목록 (2021년 04월).csv', encoding = 'euc-kr', dtype = {'ISBN': str, '세트 ISBN': str, '주제분류번호': str})

# %%
df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df.to_csv('ns_202104.csv')

# %%
with open('ns_202104.csv') as f:
  for i in range(3):
    print(f.readline(), end = '')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,인공지능과 흙,김동훈 지음,민음사,2021,9788937444319,,,,,1,0,2021-03-19,
# 1,2,가짜 행복 권하는 사회,김태형 지음,갈매나무,2021,9791190123969,,,,,1,0,2021-03-19,

# %%
ns_df = pd.read_csv('ns_202104.csv', low_memory = False)
ns_df.head()
# Out:
#    Unnamed: 0  번호                    도서명                저자    출판사  발행년도  \
# 0           0   1                인공지능과 흙            김동훈 지음    민음사  2021
# 1           1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021
# 2           2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021
# 3           3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021
# 4           4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021
#
#             ISBN 세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0  9788937444319     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1  9791190123969     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2  9788968332982     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3  9788970759906     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4  9788934990833     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
ns_df = pd.read_csv('ns_202104.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호                    도서명                저자    출판사  발행년도           ISBN  \
# 0   1                인공지능과 흙            김동훈 지음    민음사  2021  9788937444319
# 1   2           가짜 행복 권하는 사회            김태형 지음   갈매나무  2021  9791190123969
# 2   3  나도 한 문장 잘 쓰면 바랄 게 없겠네            김선영 지음   블랙피쉬  2021  9788968332982
# 3   4                예루살렘 해변  이도 게펜 지음, 임재희 옮김  문학세계사  2021  9788970759906
# 4   5  김성곤의 중국한시기행 : 장강·황하 편            김성곤 지음    김영사  2021  9788934990833
#
#   세트 ISBN 부가기호    권 주제분류번호  도서권수  대출건수        등록일자  Unnamed: 13
# 0     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 1     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 2     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 3     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN
# 4     NaN  NaN  NaN    NaN     1     0  2021-03-19          NaN

# %%
df.to_csv('ns_202104.csv', index=False)

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.9

# %%
ns_df.to_excel('ns_202104.xlsx', index=False, engine='xlsxwriter')
